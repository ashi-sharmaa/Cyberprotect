# %% [markdown]
# <a href="https://colab.research.google.com/github/ashi-sharmaa/Cyberprotect/blob/main/data_cleaning_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math
import statistics
import numpy as np
import scipy.stats
import pandas as pd

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-d9b86d67-019b-460d-bcaf-39d84acc81f3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d9b86d67-019b-460d-bcaf-39d84acc81f3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import io
dataset = pd.read_csv(io.BytesIO(uploaded['student (2).csv']))

# %%
#zoo_dataframe.drop(2, axis = 0)
#zoo_dataframe[['animals', 'section']]
#zoo_dataframe[zoo_dataframe['number'] >= 3]

# %%
dataset.shape
dataset.head()
dataset.info()
dataset.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2392 entries, 0 to 2391
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   StudentID          2392 non-null   int64
#  1   Age                2392 non-null   int64
#  2   Gender             2392 non-null   int64
#  3   Ethnicity          2392 non-null   int64
#  4   ParentalEducation  2392 non-null   int64
#  5   StudyTimeWeekly    2392 non-null   float64
#  6   Absences           2392 non-null   int64
#  7   Tutoring           2392 non-null   int64
#  8   ParentalSupport    2392 non-null   int64
#  9   Extracurricular    2392 non-null   int64
#  10  Sports             2392 non-null   int64
#  11  Music              2392 non-null   int64
#  12  Volunteering       2392 non-null   int64
#  13  GPA                2392 non-null   float64
#  14  GradeClass         2392 non-null   float64
# dtypes: float64(3), int64(12)
# memory usage: 280.4 KB
# ...

# %%
dataset.rename(columns = {'Age':'years'}, inplace = True)
dataset.head()
# Out:
#    StudentID  years  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 0       1001     17       1          0                  2        19.833723
# 1       1002     18       0          0                  1        15.408756
# 2       1003     15       0          2                  3         4.210570
# 3       1004     17       1          0                  3        10.028829
# 4       1005     17       1          0                  2         4.672495
#
#    Absences  Tutoring  ParentalSupport  Extracurricular  Sports  Music  \
# 0         7         1                2                0       0      1
# 1         0         0                1                0       0      0
# 2        26         0                2                0       0      0
# 3        14         0                3                1       0      0
# 4        17         1                3                0       0      0
#
#    Volunteering       GPA  GradeClass
# 0             0  2.929196         2.0
# ...

# %%
dataset.drop(['Gender'], axis = 1, inplace = True)
#dataset.drop(['years'], axis = 1, inplace = True)

# %%
#number of duplicate rows
dataset.duplicated().sum()
# Out:
# 0

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = (8.0, 6.0)

# %%
#for example, theres a strong negative correlation between absences and gpa,
# which means when absences are high, gpas are low
dataset.corr(numeric_only=True)
# Out:
#                    StudentID  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# StudentID           1.000000  -0.012990          -0.002307         0.026976
# Ethnicity          -0.012990   1.000000           0.033595         0.007184
# ParentalEducation  -0.002307   0.033595           1.000000        -0.011051
# StudyTimeWeekly     0.026976   0.007184          -0.011051         1.000000
# Absences            0.014841  -0.025712           0.036518         0.009326
# Tutoring           -0.007834  -0.017440          -0.017340         0.028930
# ParentalSupport     0.003016   0.020922          -0.017463         0.035800
# Extracurricular    -0.003611  -0.008927           0.007479        -0.022860
# Sports             -0.020703  -0.004484           0.002029         0.006836
# Music              -0.005468  -0.014627           0.039439         0.007791
# Volunteering        0.008011   0.013468           0.011960        -0.016604
# ...

# %%
import seaborn as sns
sns.heatmap(dataset.corr(numeric_only=True))
sns.heatmap
# Out:
# <function seaborn.matrix.heatmap(data, *, vmin=None, vmax=None, cmap=None, center=None, robust=False, annot=None, fmt='.2g', annot_kws=None, linewidths=0, linecolor='white', cbar=True, cbar_kws=None, cbar_ax=None, square=False, xticklabels='auto', yticklabels='auto', mask=None, ax=None, **kwargs)>

# %%
#line plot
plt.figure()
plt.plot(dataset['Absences'], dataset['GPA'])
plt.xlabel('Absences')
plt.ylabel('GPA')
plt.title('Absences vs GPA correlation', fontsize = 22)
plt.show()
